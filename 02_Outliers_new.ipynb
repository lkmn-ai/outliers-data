# %% [markdown]
# <a href="https://colab.research.google.com/github/lkmn-ai/outliers-data/blob/main/02_Outliers_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Outliers

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
arr1 = np.random.randint(20,60, size = (20))
arr1
# Out:
# array([55, 31, 25, 43, 46, 20, 59, 48, 27, 57, 37, 24, 55, 42, 47, 44, 22,
#        28, 53, 31])

# %%
arr2 = np.array([39, 55, 27, 27, 58, 28, 22, 44, 59, 23, 51, 32, 42, 32, 56, 43, 47, 58, 245, 257])
arr2
# Out:
# array([ 39,  55,  27,  27,  58,  28,  22,  44,  59,  23,  51,  32,  42,
#         32,  56,  43,  47,  58, 245, 257])

# %%
sns.kdeplot(arr1)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(arr2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(arr1)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(arr2)
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import skew, kurtosis

# %%
skew(arr1)
# Out:
# -0.18670395795484268

# %%
skew(arr2)
# Out:
# 2.497055735382221

# %% [markdown]
# ### 1. Z-Score Method

# %%
When data distribution is normal
Most of the values lies around mean

std >> how far away a datapoint is from mean
z_score >> how many std away a datapoint is from mean

Outlier Treatment:
    1. Trimming(Drop)
    2. Capping(Imputation)

# %%
# Standardization

z_score = (X-X_mean)/std

X >> datapoint value
X_mean >> Mean value
std >> Standard Deviation

# %%
print(arr1)
mean = np.mean(arr1)
print(f'Mean == {mean}')

std = np.std(arr1)
print(f'Std == {std}')
# Out:
# [54 56 48 43 47 47 23 44 22 37 51 25 33 33 30 30 58 44 38 47]
# Mean == 40.5
# Std == 10.707474025184466

# %%
x = 45
z_score = (x-mean)/std
z_score
# Out:
# 0.4202671880796344

# %%
x = 21
z_score = (x-mean)/std
z_score
# Out:
# -1.8211578150117491

# %%
x = 250
z_score = (x-mean)/std
z_score
# Out:
# 19.565772422818537

# %%
print(arr1)
mean = np.mean(arr1)
print(f'Mean == {mean}')

std = np.std(arr1)
print(f'Std == {std}')

threshold = 3
outliers_list = []

for x_val in arr1:
    z_score = (x_val- mean)/std
    z_score = np.abs(z_score)
    print(f'{x_val} >> {z_score}')

    if z_score > threshold:
        outliers_list.append(x_val)

print('Outliers List is :', outliers_list)
# Out:
# [54 56 48 43 47 47 23 44 22 37 51 25 33 33 30 30 58 44 38 47]
# Mean == 40.5
# Std == 10.707474025184466
# 54 >> 1.2608015642389032
# 56 >> 1.4475869811631852
# 48 >> 0.7004453134660573
# 43 >> 0.23348177115535246
# 47 >> 0.6070526050039163
# 47 >> 0.6070526050039163
# 23 >> 1.6343723980874671
# 44 >> 0.32687447961749344
# 22 >> 1.7277651065496082
# 37 >> 0.32687447961749344
# 51 >> 0.9806234388524803
# 25 >> 1.4475869811631852
# 33 >> 0.7004453134660573
# 33 >> 0.7004453134660573
# 30 >> 0.9806234388524803
# 30 >> 0.9806234388524803
# 58 >> 1.6343723980874671
# 44 >> 0.32687447961749344
# 38 >> 0.23348177115535246
# 47 >> 0.6070526050039163
# Outliers List is : []

# %%
print(arr2)
mean = np.mean(arr2)
print(f'Mean == {mean}')

std = np.std(arr2)
print(f'Std == {std}')

threshold = 3
outliers_list = []

for x_val in arr2:
    z_score = (x_val- mean)/std
    z_score = np.abs(z_score)
    print(f'{x_val} >> {z_score}')

    if z_score > threshold:
        outliers_list.append(x_val)

print('Outliers List is :', outliers_list)
# Out:
# [ 39  55  27  27  58  28  22  44  59  23  51  32  42  32  56  43  47  58
#  245 257]
# Mean == 62.25
# Std == 64.08032069208144
# 39 >> 0.36282589957251976
# 55 >> 0.11313925900648465
# 27 >> 0.5500908799970461
# 27 >> 0.5500908799970461
# 58 >> 0.06632301390035307
# 28 >> 0.5344854649616688
# 22 >> 0.628117955173932
# 44 >> 0.28479882439563375
# 59 >> 0.05071759886497588
# 23 >> 0.6125125401385548
# 51 >> 0.17556091914799343
# 32 >> 0.4720638048201601
# 42 >> 0.3160096544663882
# 32 >> 0.4720638048201601
# 56 >> 0.09753384397110745
# 43 >> 0.30040423943101097
# 47 >> 0.2379825792895022
# 58 >> 0.06632301390035307
# 245 >> 2.851889597715182
# 257 >> 3.0391545781397085
# Outliers List is : [257]

# %%
print(arr2)
mean = np.mean(arr2)
print(f'Mean == {mean}')

std = np.std(arr2)
print(f'Std == {std}')

threshold = 2
outliers_list = []

for x_val in arr2:
    z_score = (x_val- mean)/std
    z_score = np.abs(z_score)
    print(f'{x_val} >> {z_score}')

    if z_score > threshold:
        outliers_list.append(x_val)

print('Outliers List is :', outliers_list)
# Out:
# [ 39  55  27  27  58  28  22  44  59  23  51  32  42  32  56  43  47  58
#  245 257]
# Mean == 62.25
# Std == 64.08032069208144
# 39 >> 0.36282589957251976
# 55 >> 0.11313925900648465
# 27 >> 0.5500908799970461
# 27 >> 0.5500908799970461
# 58 >> 0.06632301390035307
# 28 >> 0.5344854649616688
# 22 >> 0.628117955173932
# 44 >> 0.28479882439563375
# 59 >> 0.05071759886497588
# 23 >> 0.6125125401385548
# 51 >> 0.17556091914799343
# 32 >> 0.4720638048201601
# 42 >> 0.3160096544663882
# 32 >> 0.4720638048201601
# 56 >> 0.09753384397110745
# 43 >> 0.30040423943101097
# 47 >> 0.2379825792895022
# 58 >> 0.06632301390035307
# 245 >> 2.851889597715182
# 257 >> 3.0391545781397085
# Outliers List is : [245, 257]

# %%
42 = 62.25 - z * (64.08)
z = (42 - 62.25)/64.08

# %%
(42 - 62.25)/64.08
# Out:
# -0.3160112359550562

# %%
(245 - 62.25)/64.08
# Out:
# 2.8519038701622974

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   52        1
# 3                       0.167   21        0
# ...

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
def get_outliers(feature):

    mean = feature.mean()
    print(f'Mean == {mean}')

    std = feature.std()
    print(f'Std == {std}')

    threshold = 3
    outliers_list = []

    for x_val in feature.values :
        z_score = (x_val- mean)/std
        z_score = np.abs(z_score)


        if z_score > threshold:
            print(f'{x_val} >> {z_score}')
            outliers_list.append(x_val)

    print('Outliers List is :', outliers_list)

get_outliers(df['Insulin'])
# Out:
# Mean == 79.79947916666667
# Std == 115.24400235133817
# 543 >> 4.019302622111291
# 846 >> 6.648506691892384
# 495 >> 3.6027950467004253
# 485 >> 3.516022635156495
# 495 >> 3.6027950467004253
# 478 >> 3.4552819470757434
# 744 >> 5.7634280941442935
# 680 >> 5.208084660263139
# 545 >> 4.036657104420077
# 465 >> 3.3424778120686343
# 579 >> 4.331683303669441
# 474 >> 3.420572982458171
# 480 >> 3.4726364293845298
# 600 >> 4.513905367911695
# 440 >> 3.125546783208808
# 540 >> 3.9932708986481122
# 480 >> 3.4726364293845298
# 510 >> 3.732953664016321
# Outliers List is : [543, 846, 495, 485, 495, 478, 744, 680, 545, 465, 579, 474, 480, 600, 440, 540, 480, 510]

# %%
z_score = zscore(df['Insulin'])
outliers_index = np.where(np.abs(z_score) > threshold)[0]
outliers_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 z_score = zscore(df['Insulin'])
#       2 outliers_index = np.where(np.abs(z_score) > threshold)[0]
#       3 outliers_index
#
# NameError: name 'zscore' is not defined

# %%
df['Insulin'].iloc[outliers_index]

# %%
from scipy.stats import zscore

def get_outliers(feature):

    threshold = 3

    z_score = zscore(feature)
    outliers_index = np.where(np.abs(z_score) > threshold)[0]
    print(outliers_index)

    print('Outliers List is :\n', feature.iloc[outliers_index])

get_outliers(df['Insulin'])
# Out:
# [  8  13 111 153 186 220 228 247 286 370 409 415 486 584 645 655 695 753]
# Outliers List is :
#  8      543
# 13     846
# 111    495
# 153    485
# 186    495
# 220    478
# 228    744
# 247    680
# 286    545
# 370    465
# 409    579
# 415    474
# 486    480
# 584    600
# 645    440
# 655    540
# 695    480
# 753    510
# Name: Insulin, dtype: int64

# %% [markdown]
# ### 2. IQR (Inter Quartile Range)

# %%
Use when data is not normally distributed

Boxplot:
    Median (50%ile/Q2):
        The middle value of the dataset

    1st quartile (Q1/25%ile):
        The Middle value between min and median

    3rd quartile (Q3/75%ile):
        The Middle value between max and median

IQR :
    25% to 75%

    maximum = Q3 + 1.5 * IQR
    minimum = Q1 - 1.5 * IQR

# %%
df.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   121.117188      69.076823      20.536458   79.799479   31.992578
# std     31.805091      19.367794      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    142.000000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.243490    0.348958
# std                    0.331329   11.758182    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
df['Glucose'].quantile(0.5)
# Out:
# 117.0

# %%
df['Glucose'].median()
# Out:
# 117.0

# %%
q1 = df['Glucose'].quantile(0.25)
q2 = df['Glucose'].quantile(0.5)
q3 = df['Glucose'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 1.5 * iqr
lower_tail = q1 - 1.5 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  99.0
# Q2 ==  117.0
# Q3 ==  142.0
# IQR ==  43.0
# Upper Tail ==  206.5
# Lower Tail ==  34.5

# %%
sns.boxplot(df['Glucose'])
# Out:
# <AxesSubplot:ylabel='Glucose'>

# %%
df[df['Glucose'] < lower_tail]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75         0             48             20        0  24.7
# 182        0             74             20       23  27.7
# 342        0             68             35        0  32.0
# 349        0             80             32        0  41.0
# 502        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
df[df['Glucose'] > upper_tail]
# Out:
# Empty DataFrame
# Columns: [Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
df[(df['Glucose'] > upper_tail) | (df['Glucose'] < lower_tail)]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75         0             48             20        0  24.7
# 182        0             74             20       23  27.7
# 342        0             68             35        0  32.0
# 349        0             80             32        0  41.0
# 502        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
q1 = df['Insulin'].quantile(0.25)
q2 = df['Insulin'].quantile(0.5)
q3 = df['Insulin'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 1.5 * iqr
lower_tail = q1 - 1.5 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  0.0
# Q2 ==  30.5
# Q3 ==  127.25
# IQR ==  127.25
# Upper Tail ==  318.125
# Lower Tail ==  -190.875

# %%
sns.boxplot(df['Insulin'])
# Out:
# <AxesSubplot:ylabel='Insulin'>

# %%
df[(df['Insulin'] > upper_tail) | (df['Insulin'] < lower_tail)]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8        150             70             45      543  30.5
# 13       150             60             23      846  30.1
# 54       150             66             42      342  34.7
# 111      155             62             26      495  34.0
# 139      105             72             29      325  36.9
# 153      153             82             42      485  40.6
# 186      181             68             36      495  30.1
# 220      177             60             29      478  34.6
# 228      197             70             39      744  36.7
# 231      134             80             37      370  46.2
# 247      165             90             33      680  52.3
# 248      124             70             33      402  35.4
# 258      193             50             16      375  25.9
# 286      155             84             44      545  38.7
# 296      146             70             38      360  28.0
# ...

# %%
sns.boxplot(df['BloodPressure'])
# Out:
# <AxesSubplot:ylabel='BloodPressure'>

# %%
q1 = df['BloodPressure'].quantile(0.25)
q2 = df['BloodPressure'].quantile(0.5)
q3 = df['BloodPressure'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 1.5 * iqr
lower_tail = q1 - 1.5 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  62.0
# Q2 ==  72.0
# Q3 ==  80.0
# IQR ==  18.0
# Upper Tail ==  107.0
# Lower Tail ==  35.0

# %%
df[(df['BloodPressure'] > upper_tail) | (df['BloodPressure'] < lower_tail)].shape
# Out:
# (45, 8)

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.kdeplot(titanic_df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(titanic_df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(x = titanic_df['Age'], y = titanic_df['Gender'],palette= ["skyblue", "salmon"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxplot(y = titanic_df['Age'], x = titanic_df['Survived'],palette= ["skyblue", "salmon"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(y = titanic_df['Age'], x = titanic_df['Pclass'],palette= ["skyblue", "salmon"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.scatterplot(x = df['DiabetesPedigreeFunction'], y = df['Age'], hue = df['Outcome'])
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Age'>

# %%
insurance_df = pd.read_csv('medical_insurance.csv')
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x = insurance_df['age'], y=insurance_df['bmi'], hue = insurance_df['sex'],
               style=insurance_df['smoker'], size= insurance_df['children'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %% [markdown]
# ### Handling of Outliers

# %%
1. Delete Observations
2. Imputations
3. Transformations

# %% [markdown]
# ##### Trimming (Delete)

# %%
def trim_outliers(feature):
    q1 = feature.quantile(0.25)
    q2 = feature.quantile(0.5)
    q3 = feature.quantile(0.75)

    print('Q1 == ', q1)
    print('Q2 == ', q2)
    print('Q3 == ', q3)

    iqr = q3 - q1
    print('IQR == ', iqr)

    upper_tail = q3 + 1.5 * iqr
    lower_tail = q1 - 1.5 * iqr

    print('Upper Tail == ', upper_tail)
    print('Lower Tail == ', lower_tail)

    indices = np.where((feature < lower_tail) | (feature > upper_tail))[0]
    print(indices)
    return indices

ins_outliers = trim_outliers(df['Insulin'])
# Out:
# Q1 ==  0.0
# Q2 ==  30.5
# Q3 ==  127.25
# IQR ==  127.25
# Upper Tail ==  318.125
# Lower Tail ==  -190.875
# [  8  13  54 111 139 153 186 220 228 231 247 248 258 286 296 360 370 375
#  392 409 415 480 486 519 574 584 612 645 655 695 707 710 715 753]

# %%
df1 = df.copy()
df1.shape
# Out:
# (768, 8)

# %%
df1.drop(ins_outliers)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
bp_outliers = trim_outliers(df['BloodPressure'])
df1.drop(bp_outliers)
# Out:
# Q1 ==  62.0
# Q2 ==  72.0
# Q3 ==  80.0
# IQR ==  18.0
# Upper Tail ==  107.0
# Lower Tail ==  35.0
# [  7  15  18  43  49  60  78  81  84 106 125 172 177 193 222 261 266 269
#  300 332 336 347 357 362 426 430 435 453 468 484 494 522 533 535 549 589
#  597 601 604 619 643 691 697 703 706]
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             50             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3        150             66             23       94  28.1
# 4        150             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# ...

# %% [markdown]
# ### Extreme Outliers

# %%
q1 = df['Insulin'].quantile(0.25)
q2 = df['Insulin'].quantile(0.5)
q3 = df['Insulin'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 1.5 * iqr
lower_tail = q1 - 1.5 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  0.0
# Q2 ==  30.5
# Q3 ==  127.25
# IQR ==  127.25
# Upper Tail ==  318.125
# Lower Tail ==  -190.875

# %%
df[(df['Insulin'] < lower_tail) | (df['Insulin'] > upper_tail)].shape
# Out:
# (34, 8)

# %%
q1 = df['Insulin'].quantile(0.25)
q2 = df['Insulin'].quantile(0.5)
q3 = df['Insulin'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 3 * iqr   # Extreme Outliers
lower_tail = q1 - 3 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  0.0
# Q2 ==  30.5
# Q3 ==  127.25
# IQR ==  127.25
# Upper Tail ==  509.0
# Lower Tail ==  -381.75

# %%
df[(df['Insulin'] < lower_tail) | (df['Insulin'] > upper_tail)].shape
# Out:
# (9, 8)

# %% [markdown]
# ### Imputation Technique

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
q1 = titanic_df['Fare'].quantile(0.25)
q2 = titanic_df['Fare'].quantile(0.5)
q3 = titanic_df['Fare'].quantile(0.75)

print('Q1 == ', q1)
print('Q2 == ', q2)
print('Q3 == ', q3)

iqr = q3 - q1
print('IQR == ', iqr)

upper_tail = q3 + 3 * iqr   # Extreme Outliers
lower_tail = q1 - 3 * iqr

print('Upper Tail == ', upper_tail)
print('Lower Tail == ', lower_tail)
# Out:
# Q1 ==  7.9104
# Q2 ==  14.4542
# Q3 ==  31.0
# IQR ==  23.0896
# Upper Tail ==  100.2688
# Lower Tail ==  -61.358399999999996

# %%
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
# Imputation by Median
def impute_outliers(feature):
    q1 = feature.quantile(0.25)
    q2 = feature.quantile(0.5)
    q3 = feature.quantile(0.75)

    print('Q1 == ', q1)
    print('Q2 == ', q2)
    print('Q3 == ', q3)

    iqr = q3 - q1
    print('IQR == ', iqr)

    upper_tail = q3 + 1.5 * iqr
    lower_tail = q1 - 1.5 * iqr

    print('Upper Tail == ', upper_tail)
    print('Lower Tail == ', lower_tail)

    feature.loc[feature > upper_tail] = q2
    feature.loc[feature < lower_tail] = q2

impute_outliers(df['Age'])
# Out:
# Q1 ==  24.0
# Q2 ==  29.0
# Q3 ==  41.0
# IQR ==  17.0
# Upper Tail ==  66.5
# Lower Tail ==  -1.5

# %%
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
df = df1.copy()

# %%
# Imputation by lower & upper tail
def impute_outliers(feature):
    q1 = feature.quantile(0.25)
    q2 = feature.quantile(0.5)
    q3 = feature.quantile(0.75)

    print('Q1 == ', q1)
    print('Q2 == ', q2)
    print('Q3 == ', q3)

    iqr = q3 - q1
    print('IQR == ', iqr)

    upper_tail = q3 + 1.5 * iqr
    lower_tail = q1 - 1.5 * iqr

    print('Upper Tail == ', upper_tail)
    print('Lower Tail == ', lower_tail)

    feature.loc[feature > upper_tail] = upper_tail
    feature.loc[feature < lower_tail] = lower_tail

impute_outliers(df['Age'])
# Out:
# Q1 ==  24.0
# Q2 ==  29.0
# Q3 ==  41.0
# IQR ==  17.0
# Upper Tail ==  66.5
# Lower Tail ==  -1.5

# %%
df[df['Age']>66.5]
# Out:
# Empty DataFrame
# Columns: [Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Imputation by lower & upper tail
def impute_outliers(feature):
    q1 = feature.quantile(0.25)
    q2 = feature.quantile(0.5)
    q3 = feature.quantile(0.75)

    print('Q1 == ', q1)
    print('Q2 == ', q2)
    print('Q3 == ', q3)

    iqr = q3 - q1
    print('IQR == ', iqr)

    upper_tail = q3 + 1.5 * iqr
    lower_tail = q1 - 1.5 * iqr

    print('Upper Tail == ', upper_tail)
    print('Lower Tail == ', lower_tail)

#     feature.loc[feature > upper_tail] = upper_tail
#     feature.loc[feature < lower_tail] = lower_tail
    return upper_tail, lower_tail

upper_tail, lower_tail = impute_outliers(df['Age'])
# Out:
# Q1 ==  24.0
# Q2 ==  29.0
# Q3 ==  41.0
# IQR ==  17.0
# Upper Tail ==  66.5
# Lower Tail ==  -1.5

# %%
df2 = df.copy()
df2['Age'] = np.where(df2['Age'] > upper_tail, upper_tail,
                     np.where(df2['Age'] < lower_tail , lower_tail, df2['Age']))
sns.boxplot(df2['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
upper_tail, lower_tail = impute_outliers(df['Insulin'])
df2['Insulin'] = np.where(df2['Insulin'] > upper_tail, upper_tail,
                     np.where(df2['Insulin'] < lower_tail , lower_tail, df2['Insulin']))
sns.boxplot(df2['Insulin'])
# Out:
# Q1 ==  0.0
# Q2 ==  30.5
# Q3 ==  127.25
# IQR ==  127.25
# Upper Tail ==  318.125
# Lower Tail ==  -190.875
# <AxesSubplot:ylabel='Insulin'>

# %% [markdown]
# ### Transformations

# %% [markdown]
# ##### 1. Log Transformations

# %%
Natural Log >> np.log

# %%
x = 1
print(np.log(x))
print(np.log2(x))
print(np.log10(x))
print(np.log1p(x))
# Out:
# 0.0
# 0.0
# 0.0
# 0.6931471805599453

# %%
x = 0
print(np.log(x))
print(np.log2(x))
print(np.log10(x))
print(np.log1p(x))
# Out:
# -inf
# -inf
# -inf
# 0.0

# %%
x = -10
print(np.log(x))
print(np.log2(x))
print(np.log10(x))
print(np.log1p(x))
# Out:
# nan
# nan
# nan
# nan

# %%
x = 5
print(np.log(x))
print(np.log2(x))
print(np.log10(x))
print(np.log1p(x))
# Out:
# 1.6094379124341003
# 2.321928094887362
# 0.6989700043360189
# 1.791759469228055

# %%
sns.kdeplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
skew(df['Age'])
# Out:
# 1.0640580550864676

# %%
sns.kdeplot(np.log(df['Age']))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
skew(np.log(df['Age']))
# Out:
# 0.578517187076443

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
fun_trans = FunctionTransformer(np.log)
fun_trans.fit_transform(arr1)
# Out:
# array([3.98898405, 4.02535169, 3.87120101, 3.76120012, 3.8501476 ,
#        3.8501476 , 3.13549422, 3.78418963, 3.09104245, 3.61091791,
#        3.93182563, 3.21887582, 3.49650756, 3.49650756, 3.40119738,
#        3.40119738, 4.06044301, 3.78418963, 3.63758616, 3.8501476 ])

# %%
arr1
# Out:
# array([54, 56, 48, 43, 47, 47, 23, 44, 22, 37, 51, 25, 33, 33, 30, 30, 58,
#        44, 38, 47])

# %%
fun_trans.fit_transform(df['Age'])
# Out:
# 0      3.912023
# 1      3.433987
# 2      3.951244
# 3      3.044522
# 4      3.496508
#          ...
# 763    4.143135
# 764    3.295837
# 765    3.401197
# 766    3.850148
# 767    3.135494
# Name: Age, Length: 768, dtype: float64

# %%
fit >> training/learning parameter
fit_transform >> training >> fit + transform
transform >> transform values >> training + testing

# %%
fun_trans = FunctionTransformer(np.log)
fun_trans.fit(arr1)
# Out:
# FunctionTransformer(func=<ufunc 'log'>)

# %%
fun_trans.transform(arr1)
# Out:
# array([3.98898405, 4.02535169, 3.87120101, 3.76120012, 3.8501476 ,
#        3.8501476 , 3.13549422, 3.78418963, 3.09104245, 3.61091791,
#        3.93182563, 3.21887582, 3.49650756, 3.49650756, 3.40119738,
#        3.40119738, 4.06044301, 3.78418963, 3.63758616, 3.8501476 ])

# %%
fun_trans.transform([4,5,6,7,8,9])
# Out:
# array([1.38629436, 1.60943791, 1.79175947, 1.94591015, 2.07944154,
#        2.19722458])

# %%
# from sklearn.datasets import load_boston

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

boston_df = raw_df.dropna()
boston_df.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO']
boston_df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 2     0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 4     0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 6     0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 8     0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ...       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 1002  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 1004  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 1006  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 1008  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 1010  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#       PTRATIO
# 0        15.3
# 2        17.8
# 4        17.8
# 6        18.7
# ...

# %%
boston_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(boston_df['DIS'])
# Out:
# <AxesSubplot:ylabel='DIS'>

# %%
sns.boxplot(np.log(boston_df['DIS']))
# Out:
# <AxesSubplot:ylabel='DIS'>

# %%
sns.boxplot(boston_df['B'])
# Out:
# <AxesSubplot:ylabel='B'>

# %%
sns.boxplot(np.log(boston_df['B']))
# Out:
# <AxesSubplot:ylabel='B'>

# %%
fun_trans = FunctionTransformer(np.log)
trans_values = fun_trans.fit_transform(boston_df['DIS'])
sns.boxplot(trans_values)
# Out:
# <AxesSubplot:ylabel='DIS'>

# %% [markdown]
# ##### Sqaure Root

# %%
sns.boxplot(boston_df['DIS'])
# Out:
# <AxesSubplot:ylabel='DIS'>

# %%
sns.boxplot(np.sqrt(boston_df['DIS']))
# Out:
# <AxesSubplot:ylabel='DIS'>

# %%
sns.boxplot(np.sqrt(boston_df['B']))
# Out:
# <AxesSubplot:ylabel='B'>

# %% [markdown]
# ##### Cube Root

# %%
sns.boxplot(np.cbrt(boston_df['DIS']))
# Out:
# <AxesSubplot:ylabel='DIS'>

# %%
sns.boxplot(np.cbrt(boston_df['B']))
# Out:
# <AxesSubplot:ylabel='B'>

# %% [markdown]
# ##### Square Transformation

# %%
arr1
# Out:
# array([55, 31, 25, 43, 46, 20, 59, 48, 27, 57, 37, 24, 55, 42, 47, 44, 22,
#        28, 53, 31])

# %%
arr3 = np.array([54, 56, 48, 43, 47, 1,1,2,3,4, 51, 25, 33, 33, 30, 30, 58,
       44, 38, 47])

sns.kdeplot(arr3)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(arr3 ** 2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(arr3)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(arr3 ** 2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Reciprocal

# %%
x = 1000
1/1000 = 0.001

# %%
1/1000
# Out:
# 0.001

# %%
sns.boxplot(boston_df['DIS'])
# Out:
# <Axes: ylabel='DIS'>

# %%
sns.boxplot(1/boston_df['DIS'])
# Out:
# <Axes: ylabel='DIS'>

# %%
sns.kdeplot(boston_df['ZN'])
# Out:
# <Axes: xlabel='ZN', ylabel='Density'>

# %%
sns.kdeplot(1/boston_df['ZN'])
# Out:
# <Axes: xlabel='ZN', ylabel='Density'>

# %%
sns.boxplot(boston_df['DIS'])
# Out:
# <Axes: ylabel='DIS'>

# %%
sns.boxplot(1/boston_df['DIS'])
# Out:
# <Axes: ylabel='DIS'>

# %% [markdown]
# ### Power Transformation

# %%
1. Box-Cox Transformer
2. Yeo-Johnson Transformer

# %%
Skewed Data >> Normally Distributed

x^lambda - 1/lambda

lambda >> Exponent Value

to get Normal Distribution

ranges from -5 to +5

limitation >> x == 0 or x == -ve

# %%
from sklearn.preprocessing import PowerTransformer
from scipy.stats import boxcox, skew, kurtosis, yeojohnson

# %%
sns.boxplot(df1['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.kdeplot(df1['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
age1 = boxcox(df1['Age'])[0]
sns.kdeplot(age1)
# Out:
# <Axes: ylabel='Density'>

# %%
skew(df1['Age'])
# Out:
# 1.1264266838151251

# %%
skew(age1)
# Out:
# 0.14634729789600107

# %%
sns.boxplot(df1['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(age1)
# Out:
# <Axes: >

# %%
sns.kdeplot(boston_df['ZN'])
# Out:
# <Axes: xlabel='ZN', ylabel='Density'>

# %%
sns.kdeplot(boxcox(boston_df['ZN'])[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.kdeplot(boxcox(boston_df['ZN'])[0])
#
# File ~\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1102, in boxcox(x, lmbda, alpha, optimizer)
#    1099     raise ValueError("Data must not be constant.")
#    1101 if np.any(x <= 0):
# -> 1102     raise ValueError("Data must be positive.")
#    1104 # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#    1105 lmax = boxcox_normmax(x, method='mle', optimizer=optimizer)
#
# ValueError: Data must be positive.

# %% [markdown]
# ##### Yeo-Johnson Transformer

# %%
Overcomes the limitation of boxcox (0 & -ve values)

Gaussian Distribution

Apply a power transformer featureswise to make data gaussian like

# %%
sns.boxplot(df1['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
yeojohnson(df1['Age'])[0]
# Out:
# array([0.86203442, 0.8552634 , 0.86244788, 0.84648319, 0.85636183,
#        0.85465694, 0.85174499, 0.85400697, 0.85732978, 0.86282915,
#        0.85465694, 0.85686065, 0.8633483 , 0.86366352, 0.86224542,
#        0.85583048, 0.8552634 , 0.8552634 , 0.85636183, 0.85583048,
#        0.85255685, 0.86203442, 0.85964483, 0.85400697, 0.86224542,
#        0.85964483, 0.86026677, 0.84773259, 0.8633483 , 0.85858288,
#        0.86381283, 0.85330875, 0.84773259, 0.85330875, 0.86083083,
#        0.85636183, 0.85732978, 0.86109358, 0.85255685, 0.86318177,
#        0.85174499, 0.85818877, 0.86158461, 0.86282915, 0.85930938,
#        0.85086589, 0.85400697, 0.84773259, 0.8552634 , 0.84991106,
#        0.84773259, 0.85174499, 0.85465694, 0.86350878, 0.85996357,
#        0.84648319, 0.85964483, 0.8552634 , 0.86055553, 0.84773259,
#        0.84648319, 0.85895588, 0.85777174, 0.84991106, 0.85996357,
#        0.85583048, 0.85858288, 0.86282915, 0.85086589, 0.85255685,
# ...

# %%
power_trans = PowerTransformer()
age2 = power_trans.fit_transform(df1[['Age']])
sns.boxplot(age2)
# Out:
# <Axes: >

# %%
sns.boxplot(boston_df['ZN'])
# Out:
# <Axes: ylabel='ZN'>

# %%
sns.boxplot(power_trans.fit_transform(boston_df[['ZN']]))
# Out:
# <Axes: >

# %%
power_trans = PowerTransformer(method='yeo-johnson')  # Default
age2  = power_trans.fit_transform(df1[['Age']])
sns.boxplot(age2)
# Out:
# <AxesSubplot:>

# %%
power_trans = PowerTransformer(method='box-cox')
age2  = power_trans.fit_transform(df1[['Age']])
sns.boxplot(age2)
# Out:
# <Axes: >

# %%
power_trans_bc = PowerTransformer(method='box-cox')
power_trans_yj = PowerTransformer(method='yeo-johnson')

# %%
power_trans_bc.fit_transform(boston_df[['ZN']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 power_trans_bc.fit_transform(boston_df[['ZN']])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
# ...

# %%
power_trans_yj.fit_transform(boston_df[['ZN']])
# Out:
# array([[ 1.60526992],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [ 1.54549454],
#        [ 1.54549454],
#        [ 1.54549454],
#        [ 1.54549454],
#        [ 1.54549454],
#        [ 1.54549454],
#        [ 1.54549454],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [-0.59995411],
#        [ 1.7231314 ],
#        [ 1.7231314 ],
# ...

# %%
sns.boxplot(boston_df['ZN'])
# Out:
# <AxesSubplot:ylabel='ZN'>

# %%
sns.boxplot(power_trans_yj.fit_transform(boston_df[['ZN']]))
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(boston_df['B'])
# Out:
# <AxesSubplot:ylabel='B'>

# %%
sns.boxplot(power_trans_bc.fit_transform(boston_df[['B']]))
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(power_trans_yj.fit_transform(boston_df[['B']]))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Manual Power Transform

# %%
x^ val
1/x^ val
x ^ 1/ val

# %%
100 ^ 2
1/100^ 1/4
100 ^ 1/8
